# %%
from matplotlib import pyplot as plt
import numpy as np
import sklearn
import pandas as pd
import glob
import csv

# %%
df1 = pd.read_csv('mostfreq1000docword.csv',header=None)
df1
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.047838  0.037313  0.021814  0.020475  0.020283  0.020092  0.013586
# 1    0.040797  0.031784  0.023482  0.016603  0.022770  0.022533  0.010199
# 2    0.037022  0.033041  0.016919  0.018113  0.019904  0.016322  0.013734
# 3    0.053289  0.037926  0.018243  0.024964  0.015362  0.027844  0.012962
# 4    0.051535  0.029605  0.012061  0.026316  0.025219  0.020833  0.002193
# ..        ...       ...       ...       ...       ...       ...       ...
# 426  0.049268  0.039281  0.017643  0.029627  0.019308  0.015646  0.006658
# 427  0.042038  0.026396  0.022485  0.018140  0.016185  0.013578  0.010319
# 428  0.036674  0.026976  0.026530  0.017389  0.019842  0.016052  0.009809
# 429  0.041244  0.031104  0.028569  0.017843  0.017453  0.015601  0.021743
# 430  0.051724  0.053050  0.022546  0.015915  0.009284  0.009284  0.014589
#
#           7         8         9    ...       990       991       992  \
# ...

# %%
with open('mostfreq1000word.csv') as inf:
    with open('output.csv', 'w') as outf:
        for line in inf:
            outf.write(','.join(line.split('_')))

df = pd.read_csv('output.csv', header=None, engine='python', quoting=csv.QUOTE_NONE)
df[0] = df[0].str.replace('"','nan')
df[0] = df[0].str.replace("’",'nan')
df[0] = df[0].str.replace("–",'nan')
df[0] = df[0].str.replace("-",'nan')



#for i in range(0,1000):
#    print(df.loc[[i]])
print(df.loc[[984]])
# Out:
#        0    1
# 984  nan  VBZ

# %%
df1.columns=[df[0]]
df1.reset_index(drop=True)

#df1 = df1.loc[:, df1.columns.notnull()]
#df1 = df1.drop('nan', axis=1, inplace=True)

#df2 = df1['nan']

#cond = df1['nan'].isin(df2['nan'])
#df1 = df1.drop(df1[cond].index, inplace = True)

#df2 = df1.loc[:,~df1.columns.duplicated()]
df1 = df1.loc[:,~df1.columns.duplicated()]

df1.to_csv(r'C:\Users\chria\ELEC474\251project\wordswithoutcomes.csv', index=False)
df1
# Out:
# 0         the       and        to        of         a        in        we  \
# 0    0.047838  0.037313  0.021814  0.020475  0.020283  0.020092  0.013586
# 1    0.040797  0.031784  0.023482  0.016603  0.022770  0.022533  0.010199
# 2    0.037022  0.033041  0.016919  0.018113  0.019904  0.016322  0.013734
# 3    0.053289  0.037926  0.018243  0.024964  0.015362  0.027844  0.012962
# 4    0.051535  0.029605  0.012061  0.026316  0.025219  0.020833  0.002193
# ..        ...       ...       ...       ...       ...       ...       ...
# 426  0.049268  0.039281  0.017643  0.029627  0.019308  0.015646  0.006658
# 427  0.042038  0.026396  0.022485  0.018140  0.016185  0.013578  0.010319
# 428  0.036674  0.026976  0.026530  0.017389  0.019842  0.016052  0.009809
# 429  0.041244  0.031104  0.028569  0.017843  0.017453  0.015601  0.021743
# 430  0.051724  0.053050  0.022546  0.015915  0.009284  0.009284  0.014589
#
# 0           i       for        is  ...     equal      east      walk  \
# ...

# %%
df2 = pd.read_csv('winners.csv',names=["WIN/LOSE"]
)
df2.to_csv(r'C:\Users\chria\ELEC474\251project\winnersheader.csv', index=False)

df3 = df2.join(df1)
#df3 = df3[df3.word != 'NaN'] #remove records where not a useful word
#df3.to_csv(r'C:\Users\chria\ELEC474\251project\wordsandoutcome.csv', index=False)

df3
# Out:
#      WIN/LOSE    (the,)    (and,)     (to,)     (of,)      (a,)     (in,)  \
# 0           1  0.047838  0.037313  0.021814  0.020475  0.020283  0.020092
# 1           1  0.040797  0.031784  0.023482  0.016603  0.022770  0.022533
# 2           1  0.037022  0.033041  0.016919  0.018113  0.019904  0.016322
# 3           1  0.053289  0.037926  0.018243  0.024964  0.015362  0.027844
# 4           1  0.051535  0.029605  0.012061  0.026316  0.025219  0.020833
# ..        ...       ...       ...       ...       ...       ...       ...
# 426         0  0.049268  0.039281  0.017643  0.029627  0.019308  0.015646
# 427         0  0.042038  0.026396  0.022485  0.018140  0.016185  0.013578
# 428         0  0.036674  0.026976  0.026530  0.017389  0.019842  0.016052
# 429         0  0.041244  0.031104  0.028569  0.017843  0.017453  0.015601
# 430         0  0.051724  0.053050  0.022546  0.015915  0.009284  0.009284
#
#         (we,)      (i,)    (for,)  ...  (equal,)   (east,)   (walk,)  \
# ...

# %%
#df2 = df1.sum(axis=0) 
#hist = df2.hist(bins = 1000)
#df2
#plot = df2.plot.scatter(x=df2[0], y = df2[1])

# %%
#df['Order_Date'] = df['Shipment ID'].str[:8] #group consecutive vals

# %%
#path = r'C:\Users\chria\ELEC474\251project' # use your path
#
#all_files = glob.glob(path + "/*.csv")
#
#list = []
#
#for filename in all_files:
#    fdf = pd.read_csv(filename, index_col=None, header=0)
#    list.append(df)
#
#frame = pd.concat(li, axis=0, ignore_index=True)

# %%
#df2 = pd.read_csv('mostfreq1000word.csv', engine='python', quoting=csv.QUOTE_NONE)

#datafile = open('mostfreq1000word.csv', 'r')
#csv_data = csv.reader(datafile)
